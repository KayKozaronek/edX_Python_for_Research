# %% [markdown]
# # 5.3.1: Tree-Based Methods for Regression and Classification
# - Learn about tree-based methods for regression and classification
# - Learn about the loss functions used in regression and classification settings

# %% [markdown]
# **Q: The goal of a tree-based method is typically to split up the predictor or feature space such that:**
# - *A: data within each region are as similar as possible.*
#
# **Q: For classification, how does a decision tree make a prediction for a new data point?**
# - *A: It returns the mode of the outcomes of the training data points in the predictor space where the new data point falls.*
#
# **Q: For regression, how does a decision tree make a prediction for a new data point?**
# - *A:It returns the mean of the outcomes of the training data points in the predictor space where the new data point falls.*

# %% [markdown]
# # 5.3.2: Random Forest Predictions
# - Learn how to aggregate the predictions of several trees to do random forest classification and regression
# - Learn about the two types of randomness introduced by the random forest method

# %% [markdown]
# One of the great features of the sklearn library is that there is a consistent framework for the workflow needed to use different statistical models.
#
# To do random forest regression, you use the following import:
#
# `from sklearn.ensemble import RandomForestRegressor`
#
# To do random forest classification, you use the following import:
#
# `from sklearn.ensemble import RandomForestClassifier`
#
# After importing the relevant model, everything proceeds in the same way as for linear and logistic regression.

# %% [markdown]
# Random forests get their name by introducing randomness to decision trees in two ways, once at the data level and once at the predictor level.
#
# **Q: How is randomness at the data level introduced?**
# - *A: Each tree gets a bootstrapped random sample of training data.*
#
# **Q: How is randomness at the predictor level introduced?**
# - *A: Each split only uses a subset of predictors.*
#
# **Q: In a classification setting, how does a random forest make predictions?**
# - *A: Each tree makes a prediction and the mode of these predictions is the prediction of the forest.*
#
# **Q: In a regression setting, how does a random forest make predictions?**
# - *A: Each tree makes a prediction and the mean of these predictions is the prediction of the forest.*
